# %%
#import all necessary packages
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import requests

# %%
#read in udemy_df
udemy_df = pd.read_csv('udemy_master_df.csv')
job_descriptions_df = pd.read_excel('job_descriptions.xlsx')

# %%
#remove all null values
udemy_df = udemy_df[udemy_df['Summary'].notna()]

# %%
# grouping by title to remove duplicates
job_descriptions_df = job_descriptions_df.groupby(['Title'])['Task'].apply(','.join).reset_index()

# %%
# grouping by title to remove duplicates
udemy_df = udemy_df.groupby(['Title'])['Summary'].apply(','.join).reset_index()

# %%
# creating copies of the datasets
job_df = job_descriptions_df.copy()
course_df = udemy_df.copy()

# %%
#complete keyword extraction and create word vectors from course_df using tfidfvectorizer

course_df = course_df[['Title','Summary']]

course_df  = course_df.drop_duplicates()

tfidfvec = TfidfVectorizer(
            max_df=0.7,   # note: % of docs in collection
            max_features = 10000, # only top 10k by freq,
            lowercase = True, 
            min_df=2,  # note: absolute count of documents
            stop_words="english",
            ngram_range = (1,2), # include 2-word phrases
            use_idf=True, # Enable inverse-document-frequency reweighting. If False, idf(t) = 1.
            )

vectorized_data = tfidfvec.fit_transform(course_df['Summary'])

tfidf_df = pd.DataFrame(vectorized_data.toarray(), columns=tfidfvec.get_feature_names())

tfidf_df.index = course_df['Title']

cosine_similarity_array = cosine_similarity(tfidf_df)

cosine_similarity_df = pd.DataFrame(cosine_similarity_array, columns=tfidf_df.index,index=tfidf_df.index)
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# KernelInterrupted: Execution interrupted by the Jupyter kernel.

# %%
#vectorizing the job titles for cosine similarity comparison
tfidfvec2 = TfidfVectorizer()

vectorized_data2 = tfidfvec2.fit_transform(job_df['Title'])

# %%
#vectorizing the course summaries for cosine similarity comparison

tfidfvec3 = TfidfVectorizer(
            lowercase = True, 
            ngram_range = (1,2), # include 2-word phrases
            )

vectorized_data3 = tfidfvec3.fit_transform(course_df['Summary'])

# %%
# Out:
# Search for: Customer Service Representative
# Customer service representatives, customer service advisors, or customer service associates interact with customers to handle complaints, process orders, and provide information about an organization's products and services. Customer service representatives answer questions or requests from customers or the public. They typically provide services by phone, but some also interact with customers face to face, by email or text, via live chat, and through social media.Qualifications include good communication, problem-solving, and computer skills.

# %%
def recommender(job_name,num):

    """This function takes in a job name and number as input and checks whether the job name entered
    is contained in the job dataframe titles. If it is contained in the data frame, it returns course
    recommendations for the job. If not,it searches the internet for a description of the job entered
    and if found, uses this description to match with course descriptions and returns course recommendations
    """
    
    if job_name in list(job_df['Title'].values):
        
        #get similarity between job name input and title
        query_vec = tfidfvec2.transform([job_name]) #vectorize user input job name
        similarity = cosine_similarity(query_vec, vectorized_data2).flatten() # calculate similarity with vectorized title
        indices = np.argpartition(similarity, -1)[-1:] # get 5 most similar indices
        #get the most similar summary
        #print(job_df.iloc[indices][::-1])
        job_summary = job_df.iloc[indices][::-1]['Task'].values[0] # make sure most similar is the first row and select task (summary)
      
        #get cosine similarity between course summary and job summary
        query_vec = tfidfvec3.transform([job_summary]) # vectorize the summary
        similarity = cosine_similarity(query_vec, vectorized_data3).flatten() # calculate similarity with vectorized course summary
        indices = np.argpartition(similarity, -1)[-5:]
        
        # get course name
        course_name = course_df.iloc[indices][::-1]['Title'].values[0]
        print(course_name)
        cosine_similarity_series = cosine_similarity_df.loc[course_name]
       
        ordered_similarities = cosine_similarity_series.sort_values(ascending=False)

        course_list = ordered_similarities[0:num]
        
    else:
        print('searching internet')
        response = requests.get(f"https://duckduckgo.com/?q={job_name}&va=b&t=hc&ia=web&format=json")
        results = response.json()
        information = results["AbstractText"]
        text = results["RelatedTopics"][0]["Text"]
        
        if information == "":
            job_summary = text
        else:
            job_summary = information
         
        
        #get cosine similarity between course summary and job summary
        query_vec = tfidfvec3.transform([job_summary]) # vectorize the summary
        similarity = cosine_similarity(query_vec, vectorized_data3).flatten() # calculate similarity with vectorized course summary
        indices = np.argpartition(similarity, -1)[-5:]
        
        # get course name
        course_name = course_df.iloc[indices][::-1]['Title'].values[0]
        
        cosine_similarity_series = cosine_similarity_df.loc[course_name]
        
        ordered_similarities = cosine_similarity_series.sort_values(ascending=False)

        course_list = ordered_similarities[0:num]
    
    return course_list

# %%
print(recommender('Registered Nurse',6))
# Out:
# searching internet
# Title
# Working knowledge of Accounting practice                        1.000000
# SEO, SMM & Marketing Terminology Testing                        0.529150
# Pneumatic Control                                               0.451113
# CONNECT - Become Influential and Connect with Anyone            0.391254
# Formal Languages & Finite State Automata: From the Beginning    0.351397
# Spiritual Insights for Businesses, Leaders and Entrepreneurs    0.324600
# Name: Working knowledge of Accounting practice, dtype: float64

# %%
recommender('Customer Service Representatives',5)
# Out:
# Sales Funnel Mastery For Digital Products With Clickfunnels
# Title
# Sales Funnel Mastery For Digital Products With Clickfunnels    1.000000
# How to Create An Information Product                           0.451075
# The Easy Information Product Creation System                   0.426412
# Guy Kawasaki’s The Art of Evangelism                           0.350777
# Remarkable Product Masterclass                                 0.330421
# Name: Sales Funnel Mastery For Digital Products With Clickfunnels, dtype: float64

# %%
recommender('Project Manager',5)
# Out:
# searching internet
# Title
# Project Management Essentials                                  1.000000
# Project Management Skills for Non Project Managers             0.622389
# Project Management Fundamentals: Crash Course for Beginners    0.594502
# Executive Strategy & Management                                0.569771
# Project Management (PMP) & Management Skills: Pmbok, Scrum     0.525979
# Name: Project Management Essentials, dtype: float64

# %%
recommender('Customer Service Representatives',5)
# Out:
# Sales Funnel Mastery For Digital Products With Clickfunnels
# Title
# Sales Funnel Mastery For Digital Products With Clickfunnels    1.000000
# How to Create An Information Product                           0.451075
# The Easy Information Product Creation System                   0.426412
# Guy Kawasaki’s The Art of Evangelism                           0.350777
# Remarkable Product Masterclass                                 0.330421
# Name: Sales Funnel Mastery For Digital Products With Clickfunnels, dtype: float64

# %%
recommender('Data Scientist',5)
# Out:
# searching internet
# Title
# Data Science & ML for Python-Python & Data Science Made Easy    1.000000
# Learn Data Science Basics                                       0.784355
# Complete Data Science Training with Python for Data Analysis    0.722774
# Learn Data Science From Scratch                                 0.714459
# Data Science and Machine Learning Masterclass with R            0.698815
# Name: Data Science & ML for Python-Python & Data Science Made Easy, dtype: float64

# %%
recommender('DevOps Engineer', 5)

# %%
recommender('Driver', 5)

# %%
recommender('administrative assistant',5)
# Out:
# searching internet
# Title
# Fundamentals of Administrative Professional    1.000000
# Angular4 for beginners: Learn from scratch     0.491300
# Better Business Writing Skills                 0.462754
# Art of Facebook Marketing                      0.460805
# Media Training and Interview Fundamentals      0.404912
# Name: Fundamentals of Administrative Professional, dtype: float64

# %%
job_df[job_df['Title']=='Customer Service Representatives']['Task'].values
# Out:
# array(["Confer with customers by telephone or in person to provide information about products or services, take or enter orders, cancel accounts, or obtain details of complaints.,Keep records of customer interactions or transactions, recording details of inquiries, complaints, or comments, as well as actions taken.,Check to ensure that appropriate changes were made to resolve customers' problems.,Contact customers to respond to inquiries or to notify them of claim investigation results or any planned adjustments.,Determine charges for services requested, collect deposits or payments, or arrange for billing.,Complete contract forms, prepare change of address records, or issue service discontinuance orders, using computers.,Refer unresolved customer grievances to designated departments for further investigation.,Resolve customers' service or billing complaints by performing activities such as exchanging merchandise, refunding money, or adjusting bills.,Review insurance policy terms to determine whether a particular loss is covered by insurance.,Review claims adjustments with dealers, examining parts claimed to be defective, and approving or disapproving dealers' claims.,Solicit sales of new or additional services or products.,Compare disputed merchandise with original requisitions and information from invoices and prepare invoices for returned goods.,Obtain and examine all relevant information to assess validity of complaints and to determine possible causes, such as extreme weather conditions that could increase utility bills.,Order tests that could determine the causes of product malfunctions.,Recommend improvements in products, packaging, shipping, service, or billing methods and procedures to prevent future problems."],
#       dtype=object)

# %%
course_df[course_df['Title']=='"Skyrocket your customer experience impact within weeks"']['Summary'].values
# Out:
# array(['A Customer Experience Mastermind e-course brought to you by The Experience Professionals'],
#       dtype=object)

# %%
document1 = "Solar Sales Representatives and Assessors"
document2 = "Customer Service Representatives"

documents = (
    document1,
    document2)


tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])
# Out:
# array([[0.15064018]])

# %%
document1 = "Customer Service Representatives"
document2 = "Customer Service Representatives"

documents = (
    document1,
    document2)


tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])
# Out:
# array([[1.]])

# %%
document1 = "Confer with customers by telephone or in person to provide information about products or services, take or enter orders, cancel accounts, or obtain details of complaints.,Keep records of customer interactions or transactions, recording details of inquiries, complaints, or comments, as well as actions taken.,Check to ensure that appropriate changes were made to resolve customers' problems.,Contact customers to respond to inquiries or to notify them of claim investigation results or any planned adjustments.,Determine charges for services requested, collect deposits or payments, or arrange for billing.,Complete contract forms, prepare change of address records, or issue service discontinuance orders, using computers.,Refer unresolved customer grievances to designated departments for further investigation.,Resolve customers' service or billing complaints by performing activities such as exchanging merchandise, refunding money, or adjusting bills.,Review insurance policy terms to determine whether a particular loss is covered by insurance.,Review claims adjustments with dealers, examining parts claimed to be defective, and approving or disapproving dealers' claims.,Solicit sales of new or additional services or products.,Compare disputed merchandise with original requisitions and information from invoices and prepare invoices for returned goods.,Obtain and examine all relevant information to assess validity of complaints and to determine possible causes, such as extreme weather conditions that could increase utility bills.,Order tests that could determine the causes of product malfunctions.,Recommend improvements in products, packaging, shipping, service, or billing methods and procedures to prevent future problems."
document2 = "Body Language Choreography Strategies Will Make Your Presentations and Speeches Dynamic, Memorable and Engaging!"

documents = (
    document1,
    document2)


tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

cosine_similarity(tfidf_matrix[0], tfidf_matrix[1])
# Out:
# array([[0.05524332]])

# %%
from scipy import spatial
import gensim.downloader as api

# %%
model = api.load("glove-wiki-gigaword-50")

# %%
s0 = 'Mark zuckerberg owns the facebook company'
s1 = 'Facebook company ceo is mark zuckerberg'
s2 = 'Microsoft is owned by Bill gates'
s3 = 'How to learn japanese'

def preprocess(s):
    return [i.lower() for i in s.split()]

def get_vector(s):
    return np.sum(np.array([model[i] for i in preprocess(s)]), axis=0)


print('s0 vs s1 ->',1 - spatial.distance.cosine(get_vector(s0), get_vector(s1)))
print('s0 vs s2 ->', 1 - spatial.distance.cosine(get_vector(s0), get_vector(s2)))
print('s0 vs s3 ->', 1 - spatial.distance.cosine(get_vector(s0), get_vector(s3)))
# Out:
# s0 vs s1 -> 0.965923011302948
# s0 vs s2 -> 0.8659112453460693
# s0 vs s3 -> 0.5877998471260071

# %%
list(course_df['Title'].values)
# Out:
# [' 10 Ritz-Carlton Marketing Secrets to Guarantee...',
#  ' Adobe Animate CC (Scripting): HTML5 (Español)',
#  ' Adobe Photoshop Focus Projects Course',
#  ' Affiliate Marketing - WHAT It Takes To Get To 500 A Day',
#  ' Affinity Designer - making seamless patterns',
#  ' Amazon Suspend ve Hesap Sağlığı Trademark Copyright Patent',
#  ' Animate a Logo in Adobe After Effects CC with Motion Graphic',
#  " Author School Visits 101: Marketing Children's Books",
#  ' Autodesk Revit MEP 2013',
#  ' Axure RP 9 Fundamentals and Mobile prototyping for UX Design',
#  ' Basics of Accounting (தமிழ் மொழியில் கணக்கியல் அடிப்படைகள்)',
#  ' Beginning to Draw From the Mind with Zen Doodle',
#  ' Building an Online Business while traveling the whole World',
#  ' CFA® Level 1 2014 – Quantitative Methods',
#  ' CIA Part 2- 2020 Version - 900+MCQs',
#  ' Capturing, Analyzing, and Using Lessons Learned (PMI - PMP)',
#  ' Como Crear un Plan de Marketing Digital Para Tu Sitio Web',
#  ' Complete PHP OOP Concepts for Absolute Beginners + Projects',
#  ' Complete Python Programming Masterclass Beginner to Advanced',
#  ' Create a perfect pitch deck - technology & fintech startups',
#  ' Creating Python APIs Like a BOSS - The Django REST Framework',
#  ' Curso UX Research',
#  ' Design tips for Webdesign (no code)',
#  ' Digital Transformation and Industry 4.0 Masterclass',
#  ' Exam 1 Review - Managerial Accounting (U of H)',
#  ' Fotografiar texturas para usarlas en nuestros materiales.',
#  ' From Idea to ICO the Smart Way',
#  ' Grants to Pay for Cars, Car Payments and Car Repairs',
#  ' How To Make Passive Income Selling eBooks & Courses',
#  ' Impact Investing: Making Use of Finance to Change The World',
#  ' Introduction to Python Control Flow Statements',
#  ' Kindle Success Secrets',
#  ' Lean Standard Work for Manufacturing',
#  ' Learn Twitter Sentiment Analysis with SAP® HANA® and SAPUI5',
#  ' Learn and Understand Regular Expressions(Regex)',
#  ' Learn to draw fashion with Adobe Illustrator CC - Beginners',
#  ' Master Basic Strategic Thinking and Problem Solving Skills',
#  ' Method of Investing',
#  ' Neuroscience Marketing & Persuasion [OUT NOW]',
#  ' Object-Oriented Software Engineering with Java',
#  ' Online Marketing Module Full - All In One Course',
#  ' PHP Beginner to Master',
#  ' PHP and Wordpress for Beginners',
#  ' PPC Course - How to Double Your Pay per Click Performance',
#  ' Pentaho for ETL & Data Integration Masterclass 2020- PDI 9.0',
#  ' Petroleum refining demystified - Oil & Gas industry',
#  ' Pixel Art para principiantes.',
#  ' Posicionamiento Web (SEO)',
#  ' Python 3 Masterclass step by step with coding exercises.',
#  ' React Native: Tips, Tricks, and Techniques',
#  " SQL For Databases : A Beginner's Quick Introduction",
#  ' STOP being an Entrepreneur. START being a Business!',
#  ' Selenium WebDriver MasterClass for Automation Testing',
#  ' Social Media Marketing Practice Test',
#  ' Solidworks 2018 Advanced Parts Training',
#  ' Stripe Payment Subscription Integration With PHP, HTML & CSS',
#  ' Successfully leading through change and uncertainty',
#  ' Trends of the Future for Business & Technology (2020 Update)',
#  ' Unity for kids',
#  ' Usa i podcast per far crescere la tua azienda',
#  ' Using Your Data to Grow Your Business',
#  ' Value Investing Course In Hindi',
#  ' Wagtail CMS Course | A CMS Framework for Django',
#  ' Web Development with AngularJS and Bootstrap',
#  ' Website Development Build single Page Website Parallax site',
#  ' roipins - Yabancı Siteler Kurarak Kazanç Elde Etme Kiti',
#  ' Специальные налоговые режимы',
#  '!איך לשווק ולקדם את עצמך בצורה אפקטיבית',
#  '"Autodesk Maya" Temel Düzey Modelleme ve Animasyon',
#  '"BLACK HONEY" Estrategia de SCALPING para el DAX',
#  '"BLENDER 2.79 - THE ULTIMATE GUIDE"+ 5 books+7 basic lessons',
#  '"Bitcoin für Best Ager"',
#  '"Do", Innovation, Product Design and Value Proposition',
#  '"Financial Emergency Preparation & Recovery" with Jim Jaffe',
#  '"Geometry Of Chance" - strategy of defeating roulette',
#  '"Hands On" Project Management: The Learn by Doing Approach',
#  '"Krita Basics: A Videocourse for Artists"',
#  '"Marketing Therapy." Grow Your Complementary Health Business',
#  '"Photoshop 2020", Başlangıçtan İleri Seviyeye',
#  '"Pre" Real Estate Course...are "YOU" a Real Estate Agent?!',
#  '"Promobook"',
#  '"Secretos de YOUTUBE", Aprende como tener MILES de visitas',
#  '"Skyrocket your customer experience impact within weeks"',
#  '"The Rewind Sports :60" University Intro To Sports Media 101',
#  '"Video Marketing Strategies That Never Fail"',
#  '"Write. Publish. Repeat" Conversations',
#  '"Дизайн проект" с нуля или как стать Дизайнером Интерьеров',
#  '"Как быстро найти идеального клиента"',
#  '"Платёжеспособность предприятия или деньги есть всегда!"',
#  '#1 Complete ASP.NET Core MVC Single-Page App[The Future]',
#  '#1 Complete Blockchain, Cryptocurrency, Wallet Development',
#  '#1 Complete NodeJs Express Single-Page App [The FUTURE]',
#  '#1 Cryptocurrency Investment Course: A Step-By-Step Guide',
#  '#1 Cryptocurrency Long-term Investment Opportunity 2017/2018',
#  '#1 Local SEO Strategy: Google Map SEO & Google My Business',
#  '#1 MATLAB basics',
#  '#1 Professional Email Signature Creation: Photoshop to HTML',
#  '#1 The Best Forex Trading Course',
#  '#1 Ultimate Crypto Currency Investing Program + Extras',
#  '#1 complete adobe illustrator course that covers everything!',
#  '#2 Matlab intermediate for engineers, students & scientists',
#  '#2 Scrum Product Owner -A Practical Guide For Product Owners',
#  '#3 User Stories :Master The Art Of Managing User Stories',
#  '#NAME?',
#  '#Remote PMP Management Consulting Meetings Hypnotic Edition',
#  '#ความลับการเขียนสคริปท์ "ที่ไม่มีใครบอกคุณ"',
#  "' Web scraping : Python Beautiful Soup Web scraping Bootcamp",
#  "'Powerful Business Plan' A Practical Course",
#  "'Procure to Pay' Overview",
#  "'Smart Money' Institutional Forex Trading",
#  '( Learn Autocad 2019 )اتعلم اوتوكاد 2019',
#  '(10) Ten 2D Drawings to Master 2D Sketching in Fusion 360',
#  '(20) Economics courses : Includes India and USA',
#  '(2020) Make Money: Enterprise Architect Hands-On Experience',
#  '(A تا Z) دوره جامع بازاریابی',
#  '(ACI Code)تصميم المنشأت الخرسانية حسب الكود الأمريكي',
#  '(Halloween Special) After Effects and Basic Animation',
#  '(Harmonic) تعليم الفوركس - الهارمونيك',
#  '(ManyChat) كورس احتراف شات بوت 101 للفيس بوك',
#  '(NEW) Chartboost Course 2015 - Become a Top EPCM Publisher',
#  '(NEW) Coding for non-programmers in Julia',
#  "(NEW) Create ads that don't look like ads - FB & Instagram",
#  '(NEW) How to optimise your Facebook & Instagram Ad Campaigns',
#  '(NEW) Master your bidding strategies on Facebook & Instagram',
#  '(NEW) Python Programming Course: The Complete Bootcamp',
#  '(PMI_PBA )Business Analysis Simulation Exams .',
#  '(Step by Step) Weebly Website and Google AdSense Training',
#  '(فنيات المحاسبة المالية للطلاب والخريجين (المحاسبة البسيطة',
#  '(مقدمة عن المحاسبة المالية البسيطة (اساسيات المحاسبة',
#  '* An Integrated Approach to the Fundamentals of Accounting',
#  '* Grow your sales now * Sales Rockstar plan',
#  '*Global Course* Personal Finance Concepts for All Ages',
#  '*Global Course* Real World Tips to Managing your Finances!',
#  '*NEW* DOM 2020 Build Dynamic Websites with JavaScript Part 1',
#  '*NEW* DOM 2020 Build Dynamic Websites with JavaScript Part 2',
#  '++ EMAIL MARKETING CON GET RESPONSE 2020: LA GUIDA COMPLETA',
#  '+++ AMAZON POWER 2020: How To Get Free Products Online?',
#  '+++ BITCOIN: Guadagna 207,69€ Bonus SENZA Spendere Niente',
#  '+++ LA BIBBIA PER RICEVERE PRODOTTI DA AMAZON GRATIS <',
#  '+101 Ways to Profit from Drones',
#  '+20 Ways Earn Money From Cryptocurrencies -START NOW',
#  '+40 Golden Tips for designer',
#  '+Perchè Il Conto Corrente HYPE Oltre Al Bonus Di 25€ GRATIS?',
#  '.NET 5 Web API & Entity Framework Crash Course',
#  '.NET CORE API development',
#  '.NET Continuous Integration with TeamCity',
#  '.NET Core 3.1 Web API & Entity Framework Core Jumpstart',
#  '.NET Core Microservices',
#  '.NET/C# Beginners Bootcamp',
#  '0 to 1,000 Subscribers The Correct Way',
#  '0 zu 100.000 Instagram Follower - erstellt von Influencern',
#  "0'dan 100'e Lumion - Adım Adım Acemilikten Profesyonelliğe",
#  "0'dan Business - Kurumsal Website Kodluyoruz !",
#  "0'dan Hızlandırılmış E-Ticaret Kursu(7 Kurs Entegre 1 Arada)",
#  "0'dan Uzmanlığa Gittigidiyor Satış Yapma | E-Ticaret Eğitimi",
#  '05. Рисуем драпировку',
#  '06. Рисуем Розу в графике',
#  '077 Técnicas super-secretas de Illustrator',
#  '0から1000人を集めるSNSを活用したネット集客の基本',
#  '0から作るオンラインコース入門講座：Part1【コンセプト企画・コース制作・会員サイト構築編】',
#  '0から作るオンラインコース入門講座：Part2【集客・販売・収益アップ編】',
#  '0から分かるストックビジネスの入門書',
#  '1 Day Digital Agency',
#  '1 Günde 0 dan 1 e WordPress',
#  '1 Hour Button Master',
#  '1 Hour CSS',
#  '1 Hour HTML',
#  '1 Hour JavaScript',
#  '1 Hour Programming with Python',
#  '1 Hour Wordpress Web Design - Build a site with no coding!',
#  '1 Hour Wordpress – Create a Beautiful Website or Blog',
#  '1 Hour to Better Content Writing',
#  '1 Hour to Better, More Productive Blogging',
#  '1 Saatte Harika Websiteler Hazırlamayı Öğrenin!',
#  '1 day MVP 2.0 | Go from idea to MVP in just 1 day',
#  '1 day WordPress website for your business, affiliate or blog',
#  '1 hour corporate training - Coding for beginners',
#  '1 hour jQuery',
#  '1) Rapid Systems Development for Business Transformation',
#  '1+1 = Podcast: A Simple Formula for Podcasting Success',
#  '1-Hour Wordpress Basic Tutorial',
#  '1. APICS CPIM Practice Questions (200 Questions)',
#  '1. Principles of Simple Interest',
#  '10 Adobe After Effects projects to create right away!',
#  '10 Alternatives Marketing You Should Know in this IR 4.0 Era',
#  '10 Best Government Grants to Start a Non-Profit in America',
#  '10 Best Online Marketing Strategies',
#  '10 Biggest Mistakes When Searching for Government Grants',
#  '10 Cool Ways To Get More Action From Your Marketing Emails',
#  '10 Copywriting Hacks That Work in 2020',
#  '10 Dropshipping Product Categories That Make Me 6-Figures',
#  '10 Effective Offline Marketing Strategies Great For 2020',
#  '10 Email Marketing Strategies That Make Me 6-Figures',
#  '10 Estrategias de marketing móvil que utiliza SPOTIFY',
#  '10 Facebook Ads Golden Principles That Make Me 6-Figures',
#  '10 Facebook Ads Strategies That Make Me 6-Figures',
#  '10 Facebook Marketing Hacks That Work In 2020',
#  '10 Facebook Marketing Strategies That Make Me 6-Figures',
#  '10 Good Reasons Why You Should Invest in Real Estate',
#  '10 Guaranteed Ways to Monetize Your Content on YouTube',
#  '10 Hacks To Increase Fan Engagement On Facebook',
#  '10 Influencer Marketing Strategies That Make Me 6-Figures',
#  '10 Instagram Growth Secrets From Celebrities & Influencers',
#  '10 Instagram Marketing Strategies That Make Me 6-Figures',
#  '10 Killer Tips and Tricks for Unity',
#  '10 Nouveaux Ateliers Pratiques sur Adobe After Effects CC',
#  '10 Numbers Every Business Owner Should Know',
#  '10 Online Business Models That Make Me 6-Figures',
#  '10 Passive Income Businesses - Earn Passive Income In 2020',
#  '10 Perfect Lead Magnet Ideas For Bloggers',
#  '10 Perfect Lead Magnet Ideas For Coaches And Consultants',
#  '10 Perfect Lead Magnet Ideas For Fiction Authors',
#  '10 Perfect Lead Magnet Ideas For Freelancers',
#  '10 Perfect Lead Magnet Ideas For Nonfiction Authors',
#  '10 Perfect Lead Magnet Ideas For Online Instructors',
#  '10 Proven Ways to Earn More on Fiverr',
#  '10 Second Cartooning',
#  '10 Secrets How to compete with online roulette using system',
#  '10 Shopify Dropshipping Strategies That Make Me 6-Figures',
#  '10 Simple Steps To Increase Revenue',
#  '10 Step Digital Product Blueprint for Passive Income',
#  '10 Steps To Your Awesome Service Provider Website',
#  '10 Steps to Replacing Workplace Bullying',
#  '10 Teaching Secret to Grow Up Your Teacher Business',
#  "10 Things Authors Do to Sabotage Their Book's Success",
#  '10 Things Every Coach or Consultant Needs to Know to Succeed',
#  '10 Things you must know in Photoshop',
#  '10 Trucchi per Migliorare il Coinvolgimento sulla FanPage',
#  '10 Ways to Enhance User Experience on a Mobile Website',
#  '10 YouTube Marketing Strategies That Make Me 6-Figures',
#  '10 jours maîtriser vos investissements sur le marché crypto',
#  '10+1 Facebook Marketing Steps to Increase Sales',
#  '10. Bonds and Bond Pricing',
#  '100 Algorithms Challenge',
#  '100 Front End Interview Questions Challenge',
#  '100 Interactive Python Exercises to Boost Your Python Skill',
#  '100 Marketing tips - for everyday marketing',
#  '100 Practical Sales Skills & Sales Tips To increase Sales',
#  '100 Practical Tips for Success in Your Business Career',
#  '100 Python Exercises: Evaluate and Improve Your Skills',
#  '100 SQL Problem Scenario and Solutions - Volume 1',
#  '100 Single Page Mini Websites 100x Profit - Amazon Affiliate',
#  '100 Social Media Tips, Tricks & Techniques',
#  '100 Usable WordPress Code Snippets for Themes & Plugins 2019',
#  '100 idées de contenus pour vos réseaux sociaux',
#  '100% Mahir Perencanaan Keuangan',
#  '100% Sure Success in Day Trading : My SECRET™ Strategy',
#  '100+ Fundraising Ideas for Your Non-Profit',
#  '100+ Manual Test Cases- Interview Preparation',
#  '1000% Landing Page Optimization & Sales Funnel Conversion',
#  '1000+ CAPM Q&A - PMBOK Guide 6th edition',
#  "101 Crucial Lessons They Don't Teach You In Business School",
#  '101 Hypnosis Downloads Get The Life You Desire with Hypnosis',
#  '10k Digital Master (BluePrint)',
#  '11 Essential Coding Interview Questions + Coding Exercises!',
#  '11 Estrategias Poderosas para Generar Tráfico Web Gratis',
#  '11 Free Ways To Get Mass Traffic To Your Website in 2020!',
#  '11 JavaScript Features Critical to Understand',
#  '11 Marketing Fundamentals to Build a Profitable Business',
#  '11 Étapes pour développer une puissante STRATÉGIE DIGITALE',
#  '12 Creative Glitch Projects in Photoshop - secrets revealed',
#  '12 Days SEO Bootcamp|Rank #1 on Google|Complete SEO Guide',
#  '12 Easy Steps ✔ to the Python Data Analysis, Beginners Guide',
#  '12 Microeconomics courses (24 hrs) ... Accredited',
#  '12 Proven SEO Tips That Gets Traffic To WordPress Websites',
#  '12 Proven Ways To Make Money Online',
#  '12 Secrets to Be a Professional Executive Assistant Gaby',
#  '12 Signals to Master Any Market',
#  '12 Steps Business Case Development',
#  '12 Steps to Your Financial Independence',
#  '12 Steps to build your own Website with WordPress',
#  '12 Strategies for Dealing With Difficult People',
#  '12 Technical & Business Writing Power Techniques for Success',
#  '12 Things about finance that entrepreneurs need to know',
#  '12 Weekend Coding projects for beginners from scratch',
#  '12 courses in Macroeconomics (29 hrs in total) - August 2020',
#  '12 in 1 sales masterclass: sales skills & influence mastery',
#  '1200 Questions PMP Certification Exam Prep PMBOK Test',
#  '12th Accountancy (Fundamental of Partnership), by Nitin Sir',
#  '12th Accountancy CBSE',
#  '13 Easy Steps to Transform New Hire to Superstar',
#  '13 Easy Ways to Get Traffic to Your Website',
#  '13 Fontes de Renda na Internet em 2020',
#  '13 Linkedin Lead Generation Hacks',
#  '13 Secrets of Pricing Psychology: Boost Your Profits Today',
#  '13 Techniques pour créer des sélections sur Photoshop CC',
#  '14 Authority Sites For Learning Amazon Affiliate Marketing',
#  '14 Day InstaSales Challenge For Shopify Merchants',
#  '14 Reasons why entrepreneurs consistently fail in business',
#  '14 Ways to DIY: Mobile App Builders',
#  '14 in 1 Home Business Course - Choose Your Next Online Biz!',
#  '15 Cool Ways To Interact With Your Email Subscribers',
#  '15 Cursos em 1 Formação Autodesk Maya',
#  '15 Economic problems facing the Prime Minister in the 2020s',
#  '15 Minutes to Facebook Fabulous',
#  '15 Motion Graphic Elements in After Effect (Series 2)',
#  '15 Powerful strategies to monetize your TikTok account',
#  "150 students/year as an independent tutor. Here's how.",
#  '155 Years of Copywriting Insights Taught In 1.5 Hour Course!',
#  '16 beginner programming projects: Java, Python,JavaScript,c#',
#  '17 Bancos de Imagens Gratuitos',
#  '17 Beginner C# Walkthrough Projects step by step',
#  '17 Complete JavaScript projects explained step by step',
#  '17 Power Tips To Create The Perfect Landing page',
#  '17 Proven Strategies to Get More Clients With Social Media',
#  '17 Ways to Maximize Reddit for Your Business',
#  '170+ iOS 11 & Swift 4 Interview Questions',
#  '18 Essential Features in MS Excel',
#  '18 способов получить больше подписчиков на YouTube канал',
#  '188% Profit in 1Year - Forex ALGO Robot Trading no indicator',
#  '19 FREE Tools to Create Visuals for Web and Social Media',
#  '190+ Android Interview Questions',
#  '1S MBA - Marketing Contábil',
#  '1S MBA - Marketing Jurídico',
#  '1Z0-071 Oracle Database SQL Developer: Certified Associate',
#  '1万円以下の商品を販売するためのステップメールの作り方',
#  '1時間30分でわかる\u3000漫画アフィリエイトメソッド',
#  '1時間でWordPressを使いホームページを完成させる方法',
#  '2 Cent Facebook Clicks - Cheap Targeted Traffic',
#  '2 in 1: Complete Excel + Data Analysis Application & Theory',
#  '2 titoli azionari facili e semplici per fare soldi trading',
#  '2 ve 4 Borulu Fan Coil Nedir ? Nasıl Tasarlanır ?',
#  '2-Hour Digital Products: Learn How to Create & Sell Online',
#  '2-Second Website Speed Optimization In 1 Day - Technical SEO',
#  '2. APICS CPIM Practice Questions (175 Questions)',
#  '2. Principles of Simple Interest - advanced problems',
#  '20 Ateliers Pratiques sur Adobe After Effects CC',
#  '20 Best Communication Hacks: Influence and Persuade People',
#  '20 Colossal Business Mistakes',
#  '20 Dakikada Kod Bilmeden Web Sitesi Kur (EnDüşükMaliyetle)',
#  '20 Important steps to prepare the design for printing.',
#  '20 Queries - SUBQUERIES',
#  '20 Ways To Make Money Online',
#  '20 Web Projects With Vanilla JavaScript',
#  '20 easy tipps to start your own internet business',
#  '20 lessons I learned in Dental Business Management',
#  '20 steps to develop a successful entrepreneurial mindset',
#  '200+ Exercises - Programming in Python - from A to Z',
#  '2016 Blog Blueprint: How I Replaced My Day Job With My Blog',
#  '2017 Affiliate Marketing + SEO Strategy - Mastery Course',
#  '2017 ETSY SEO - Search Engine Optimization - More Sales Now!',
#  '2017 Etsy Shop Complete Guide and Tricks',
#  '2017년 최신 그로스 해킹 핵심 강좌 - Growth Hacking Fundamentals',
#  '2018 Cryptocurrency Masterclass: Trading & Investment Course',
#  '2018 Ebay Business - Powerseller Selling Secrets, SEO, Hacks',
#  '2018 SEO Course: Quickly learn SEO for Small Business Owners',
#  '2018 SEO: Complete Step by Step Task Guide (Beginners)',
#  '2018 TBDY GÖRE STA4CAD İLE STATİK PROJE EĞİTİMİ',
#  '2018 Tax Law Changes',
#  '2018 Web Design No Coding Basic HTML5 or CSS3- Easy Websites',
#  '2018年必備的 35個小編工具箱',
#  '2019 Authority Blogging: Step By Step For Beginners',
#  '2019 Blog Blueprint: How To Turn Blogging Into A Career',
#  "2019 Calendar App: Let's Build It!",
#  '2019 Clickfunnels Training',
#  '2019 Facebook Ads Marketing Course',
#  '2019 PHP Starter Kit - A Complete Ultimate Starter Kit',
#  '2019 build a translate online app with vue js',
#  '2020 - 5 Steps To Turn Your Idea Into A Profitable Business',
#  '2020 - Build Targeted Mailing List Today Without a Website',
#  '2020 - How To Start An Ecommerce Business: Amazon, Ads & SEO',
#  '2020 : Complete SEO training for wordpress (onpage+offpage)',
#  '2020 A-Z™ Google Ads (Adwords) Dijital Pazarlama Eğitimi',
#  '2020 Bitcoin Beginners Course',
#  '2020 Blogging Bootcamp: Build a Successful & Profitable Blog',
#  '2020 Blueprint on Forex Trading: Complete Success Manuscript',
#  '2020 Build an app like tiktok using vue js',
#  '2020 Complete Course: The Accounting External Audit Process',
#  '2020 Complete Instagram Marketing Masterclass: Become a Pro',
#  '2020 Complete Marketing Masterclass #1 | Your Model',
#  '2020 Complete Marketing Masterclass #2 | Belief Framework',
#  '2020 Complete Marketing Masterclass #3 | CRO',
#  '2020 Complete Marketing Masterclass #4 | SEO',
#  '2020 Complete Marketing Masterclass #5 | Content Strategy',
#  '2020 Complete Marketing Masterclass #6 | Multi-Channel Leads',
#  '2020 Complete Python Bootcamp: From Zero to Hero in Python',
#  '2020 Complete SEO Guide to Ranking Local Business Websites',
#  '2020 Detaylı Facebook & Instagram Reklamcılığı Eğitim Seti',
#  '2020 Domain Name & Website Flipping Profits With A Twist',
#  '2020 Email Marketing Masterclass',
#  '2020 Facebook Ads & Instagram Ads | Social marketing',
#  '2020 Financial Reporting: How To Recover From A Down Quarter',
#  '2020 Free Google Website, Free Elementor, Free Astra Theme',
#  '2020 Fullstack: Full Laravel with QRCodes, APIs, Android/iOS',
#  '2020 Guide to Generating Leads With Google Local Service Ads',
#  '2020 Guide to Monetizing Your Website or Blog',
#  '2020 Instagram Masterclass: The ROAD TO 1 MILLION FOLLOWERS',
#  '2020 Manager Guide to Performance Management',
#  '2020 Mobile App Marketing & App Store Optimization ASO',
#  '2020 Mural masterclass: Supercharge your remote workshops',
#  '2020 New Google Ads (AdWords) Course - From Beginner to PRO',
#  '2020 Part1 CIA Exam- Essentials of Internal Auditing',
#  '2020 Part2 CIA Exam- Practice of Internal Auditing',
#  '2020 Part3 CIA- Business Knowledge for Internal Auditing',
#  '2020 Python Regular Expressions (Regex) with Projects',
#  '2020 SEO New - Become An SEO Expert With Yoast SEO Plugin',
#  '2020 SEO Strategy: Keyword Research, Audit & Link Building',
#  '2020 SEO Training Masterclass: Beginner SEO To Advanced SEO',
#  '2020 SEO for Beginners - Rank on the Top from Today!',
#  '2020 Selling On Amazon: Amazon SEO, Ads, Ecommerce Marketing',
#  '2020 Strategic Wealth Generator - NLP Program Level 1*****',
#  '2020 Ultimate Guide to YouTube Channel & YouTube Masterclass',
#  '2020 Ultimate Transcription and Captioning Course',
#  '2020 Video Marketing & Advertising Via Effective YouTube Ads',
#  '2020 Wordpress SEO Masterclass: Free Traffic to your Website',
#  '2020 YouTube Marketing & YouTube SEO To Get 1,000,000+ Views',
#  '2020 YouTube Masterclass - Complete Guide to YouTube Success',
#  '2020 YouTube Mastery Quick Start Marketing Course',
#  '2020 Youtube Hack: Paying For Engagement, Not Only Clicks!',
#  '2020 create a Flappy Bird game with python3.8',
#  '2020 create a Snakey Game with python3.8',
#  '2020 instagram marketing : complete masterclass',
#  '2020 learning python3.8 from beginner to the master',
#  '2020 كورس فيسبوك ادز 101 بالعربي - احتراف اعلانات الفيس بوك',
#  '2020-21 Complete US Accounting Standards Based Course',
#  '2020-21 Updated : Bookkeeping & Accountancy Complete Course',
#  '2020-21 Updated Basic Accounting & Bookkeeping For Beginners',
#  '2020-PARA KAZANMA SANATI ( Fonlarla Herşeye Yatırım Yapmak )',
#  '2020/21 CFA® Level 1 Fixed Income - Learn by Practice',
#  '2020/21 CFA® Level 1 Quantitative Methods-Learn by Practice',
#  '2020: Find & Buy Premium-Looking Domain Names Cheaply',
#  '2020: How To Choose a Winning Amazon FBA Product Every Time',
#  '2020|Wordpress ile Sıfırdan İnternet Sitesi Oluşturma',
#  '2020年度 Google Ads（グーグル広告）基礎・概論編\u3000最新・保存版',
#  '2020年度 Google Ads（グーグル広告）設定＆運用ガイド 最新・保存版',
#  '2021 CIVIL ENGINEERING WORLDWIDE JOB OPPORTUNITIES & CAREERS',
#  '21 CFR Part 820 (Medical Device QSR) - Practice Exam',
#  '21 Copywriting Hacks (Marketing psychology and Persuasion) .',
#  '21 Copywriting Hacks That Deliver Quick And Easy Wins',
#  '21 Email Etiquette Rules Every Professional Should Follow',
#  '21 Instagram marketing keypoints to change your Business',
#  '21 Local Business Lead Generation Strategies to Use in 2020',
#  '21 Steps to Becoming a Virtual Assistant',
#  '21 Steps to Start Speaking More Smoothly & Confidently',
#  '21 Steps to Successful Project Management',
#  '21 Strategies to Build GREAT Credit!',
#  '21st Century Branding | Powerful Brand Building Strategies',
#  '21st Century Presentation Skills',
#  '22 Ways To Earn Money Online That Make Money In 2020',
#  '22 Weird Tricks To Get Your Emails Opened',
#  '24h Pro data science in R',
#  '25 Best Practices of Webinar Presenting',
#  '25 Business Analysis by Data Visualizations in Tableau',
#  '25 FALLEN auf dem Weg zur finanziellen Unabhängigkeit',
#  '25 Mistakes You Make in Email Marketing & How To Fix Them',
#  '25 Sales Strategies for B2B & B2C: The Complete Course',
#  '25 Sales Strategies for B2B: The Complete B2B Masterclass',
#  '25+ Tips On Creating Captivating Slide Presentations!',
#  '25+ Ways To Promote Your Blog and Increase Website Traffic',
#  '27 Best Free WordPress Plugins For Business & Entrepreneurs',
#  '27 GIMP 2.10 Projects + 547 GIMP Templates',
#  '27 Photoshop CC Projects + 547 Photoshop Essentials Template',
#  '27 Practical SQL Queries to solve Business Problems',
#  '27 Super Traffic Techniques To Double Your Blog Visitors',
#  '27 Weird Tricks To Get More Email Clicks',
#  '27 Youtube Profi Tipps für mehr Erfolg im Video-Marketing',
#  '28 Easy Ways to Increase Your Reach for Musicians',
#  '28 Time Saving Tips & Tricks In Adobe Photoshop',
#  '29 Proven Tips on Buying and Managing Rental Property',
#  '299 Personal Grants for Houston Flood Victims To Live On',
#  '2D Adventure Game Creation: Art, Music, Programming and More',
#  '2D Animation Essentials in Moho & Anime Studio',
#  '2D Animation For Beginners , Easy , Fast and Simple',
#  '2D Animation With No Drawing Skills in AE',
#  '2D Animation for any users (Cutout style)',
#  '2D Animation in Moho from Basic to Advanced',
#  '2D Animation of a Fire Pit in After Effects for Beginners',
#  '2D Animation with CSS Animations - Complete course, project',
#  '2D Animation: Ultimate Guide to Adobe Animate',
#  '2D Animationsfilme und Erklärvideos selber erstellen',
#  '2D Character Animation: Dialogue and Acting',
#  '2D Character Animation: Walk Cycles',
#  '2D Character Design in Blender',
#  '2D Composition in Photoshop & Animation in After Effects',
#  '2D Game Art for Non-Artists',
#  '2D Game Artist: Design Pixel Art From Scratch',
#  '2D Game Assets Design in Photoshop - The Lazy Way',
#  '2D Game Development : Build 7 Android iOS 2D Games using C#',
#  '2D Game Development W/ Javascript & CSS3- Create Memory Game',
#  '2D Game Development With HTML5 Canvas, JS - Tic Tac Toe Game',
#  '2D Industrial Design with Cad',
#  '2D ve 3D AutoCAD',
#  '2D-анимация в Blender',
#  '2Shapes Cloud: From zero to hero',
#  '2d Bitmap art for video games',
#  '2d cartoon creation in Moho 12',
#  '2週間でマスターするダイレクト・レスポンス・マーケティング入門',
#  '3 BOYUTLU TASARIM VE BASKI EĞİTİMİ',
#  '3 Boyutlu Giysi Tasarımı CLO 3D/Marvelous Designer',
#  '3 Combo Strategy - Forex Price Action MASTERCLASS',
#  '3 Day Nonfiction Book System - Nonfiction E-book Writing',
#  '3 FOREX Trade Management techniques for profitable trading',
#  '3 Hot Affiliate Marketing Campaigns Done For You!',
#  '3 Hour Wireframing and Prototyping',
#  '3 Kurs Bir Arada - Dijital Pazarlama | E-Ticaret | SEO',
#  "3 Low Cost Business Tips By America's #1 Wine Brand Founders",
#  '3 Master Steps to Retire on Cashflow Investing Stock Option',
#  '3 Online Business / Side Hustle Ideas For Sports Fans',
#  '3 Pilares do Sucesso Financeiro Empresarial',
#  '3 Profitable Online Business Methods For 2017',
#  '3 STEPS TO RAISING CAPITAL FAST [FULL]',
#  '3 Step Viral Marketing: 3 Effective Ways to Drive Traffic!',
#  '3 Steps To Improve Your Communications Skills',
#  '3 Ways to To Build An Online Business with Arbitrage',
#  '3 documentos clave para administrar tu empresa con éxito',
#  '3 steps Python Blueprint',
#  '3-Easy-Pieces / Effortless Effective Writing Essentials',
#  '3-Step Writing System: Blogging & Writing Secrets [2020]',
#  '3. Compound Interest',
#  '30 Copywriting Secrets from the Best Ad Campaign of All Time',
#  '30 Day Blog Transformation Challenge',
#  '30 Day Challenge: Step by Step Online Business Success',
#  '30 Day Digital Agency',
#  '30 Day Marketing Plan For Estate Agents To Improve Sales',
#  '30 Days of Python | Unlock your Python Potential',
#  '30 Days of Swift: Learn the Basics & Build an iOS App.',
#  '30 Facebook Marketing Hacks: Der Komplette Facebook Kurs',
#  '30 GOLDENE AKTIEN GEBOTE: Börse und Aktienhandel lernen',
#  '30 Minute Meetings: Hold Faster Meetings & Boost Efficiency!',
#  '30 Minute Swift Crash Course. Use Labels in Xcode',
#  '30 Side Hustle / Business Ideas That You Can Start Today',
#  '30 Smart Marketing Tips for your Tourism Business',
#  '30 Tricks zu YouTube-SEO. Per Video-Marketing Geld verdienen',
#  '30 Ways to Get Traffic to Your Real Estate Business',
#  '30 day brand strategy',
#  '30 jrs pour avoir votre Business (dropshipping) clé en main',
#  '30 min to Keto',
#  '30 minutes only for Whiteboard Animation',
#  '30+ Google Tools you need to know about, NOW',
#  '30-day Business Blast',
#  '30-minute MBA in Branding+Brand Management+Branding Strategy',
#  '300+ Q&As - Ace your Android Developer Test or Interview',
#  '30分でわかる！初めてのチラシ作り～小さなお店の売上をアップする販売促進',
#  '30分でわかる！初めてのレター作り～小さなお店の売上をアップする販売促進',
#  '30分でわかる！初めてのＰＯＰ作り～小さなお店の売上をアップする販売促進',
#  '31 Days of Online Marketing Ideas',
#  '31 Days to Get Your Business on Track',
#  '33 Técnicas para aumentar a conversão de lojas virtuais',
#  '35-Minute Mastery: Enterprise B2B Sales Condensed',
#  '360 Digital Marketing',
#  '360 Grad Architektur mit Unity und Cinema 4D',
#  '360 Marketing Strategy: How Unknown Brands Gain Loyal Fans',
#  '360° Dijital Pazarlama Eğitimi',
#  '365 Days of Creativity',
#  '38 Java String-Related Techniques Making Your Life Easier',
#  '3D ANIMATION - 0 to PRO: Create Credible & Unique Animations',
#  '3D ANIMATION: WALK and RUN CYCLE',
#  '3D Animation & Data Visualization in Autodesk Maya',
#  '3D Animation & Modeling Master Class | Beginner to Advanced',
#  '3D Animation Film-Making with Plotagon Certification',
#  '3D Animation for Architecture 3ds max + Vray (phase 1)',
#  '3D Animation using Unity Timeline',
#  '3D Animation with Blender 2.8x for beginners',
#  '3D Animation: Basics To Full Body and Creature Mechanics',
#  '3D Asset Creation for Unity 2019 - Shipping Container',
#  '3D CAD Fundamentals with SIEMENS Solid Edge',
#  '3D Character Creation in Cinema 4D: Modeling a 3D Robot',
#  '3D Character Creation in Cinema 4D: Modeling a Happy Monster',
#  '3D Character Creation: Retopologizing For Animation - Zbrush',
#  '3D Character Creation: Sculpting in Zbrush',
#  '3D Character Walk Cycle Animation with Maya for Beginners',
#  '3D Characters in Unity',
#  '3D Coat 4- Volume 1: Getting Started',
#  '3D Coat: Smart masks, smart materials',
#  '3D Druck & Maker Komplettkurs: 3D Drucken für Jeden!',
#  '3D Face Modeling for Beginners using Autodesk Maya',
#  '3D Game Asset: Turret - Maya, Substance Painter, and Unity',
#  '3D Game Character Creature - Full Complete Pipeline',
#  '3D Game Development with Blender',
#  '3D Game Environment Cathedral Creation',
#  '3D Game Modeling & Animation With Blender',
#  '3D House Design Mastery in Blender - Graphics & Design',
#  '3D House Design in Blender: Make Low Poly Art for Unity®',
#  '3D House Illustration with Adobe Illustrator for beginner',
#  '3D Illustration on Blender 2.8 -3D for Aspiring Illustrators',
#  '3D Jewelry Rendering Using Keyshot',
#  '3D Lighting - Theory and Practice',
#  '3D Lighting and Rendering with Maya and Arnold - Drone',
#  '3D Logo Design using Autodesk 3ds Max',
#  '3D Logo Design using Autodesk Maya',
#  '3D Logo Design using Cinema 4D R20',
#  '3D Logo Reveal Animation',
#  '3D Master, from zero to hero Vol.1: Zbrush Basics',
#  '3D Master, from zero to hero Vol.4: Body Anatomy',
#  '3D Master, from zero to hero Vol.5: Head Anatomy',
#  '3D Master, from zero to hero Vol.6: Hands and Feet',
#  '3D Max Modeling from beginner to advanced',
#  '3D Max: textura e render do básico ao avançado (+3 Bonus)',
#  '3D Medical Animation in Autodesk Maya',
#  '3D Model and Texture a High Quality Game Prop Gun Rifle',
#  '3D Modeling & Animation with Maya',
#  '3D Modeling Bootcamp in Blender - The 3D creator course',
#  '3D Modeling In Mudbox - A Definitive Mudbox Tutorial',
#  '3D Modeling Piped Systems in AutoCAD',
#  '3D Modeling With Maya: How to Model 3D Weapons From Scratch!',
#  '3D Modeling and Texturing Interior Office in Autodesk Maya',
#  '3D Modeling and texturing for games',
#  '3D Modeling for Video Games : Beginners Guide',
#  '3D Modeling from zero to Professional with 3D Max',
#  '3D Modeling in Blender 2.8 for Unity Video Game Developers',
#  '3D Modeling in Photoshop - An In Depth Tutorial',
#  '3D Modeling: Learn creating assets in Blender',
#  '3D Modelling in Blender',
#  '3D Modelling with 3ds Max : The Quickest Way',
#  '3D Motion Graphics: An Introduction',
#  '3D Objects in Apple Motion 5 a 2020 Update',
#  '3D Painting using FlowScape: Paint Dream Worlds in 3D',
#  '3D Photorealistic Architectural Visualization',
#  '3D Photoshop',
#  '3D Pixel Art for non artist. Crossy Road Modeling. Unity 3D',
#  '3D Pixel Characters Modeling & Animations for all. Unity 3D',
#  '3D Printing',
#  '3D Printing Basics',
#  '3D Printing Business Secrets: From Modeling to Marketing',
#  '3D Printing Quickstart with SketchUp Make',
#  '3D Printing and Tinkercad Crash Course',
#  '3D Printing from Zero to Hero in Blender 2.9x - 3D Design',
#  '3D Printing using fusion 360',
#  '3D Printing: From Start to Finish',
#  '3D Procedural Mesh Generation Fundamentals in Unity',
#  '3D Product Visualization in Cinema 4D - Energy Drink Poster',
#  '3D Programming with JavaScript and the Three.js 3D Library',
#  '3D Reference Modeling Using Blender 2.8',
#  '3D Rendering with Keyshot',
#  '3D Resin Printing: From Start to Finish',
#  '3D Studio Max - Dicas Avançadas',
#  '3D Studio Max - Ferramentas de Animação',
#  '3D Studio Max - Programação em MaxScript',
#  '3D Studio Max 2017: modellare e renderizzare un interno',
#  '3D Studio Max 2018 para Games & VR',
#  '3D Studio Max 2019 - Mapeamento UVW e Textura do Personagem',
#  '3D Studio Max 2019 Animasyon Particle Systems',
#  '3D Studio Max Aprende a Representar Espacios Arquitectónicos',
#  '3D Studio Max Character Studio e Skin para Rig de Personagem',
#  '3D Studio Max Foundation',
#  '3D Studio Max e Unity - Realidade Aumentada do Zero',
#  '3D Studio Max livello base',
#  '3D Studio Max: Espacios arquitectónicos',
#  '3D Studio Rendering with 3ds Max + Vray : The Quickest Way',
#  '3D Text Animation in Autodesk Maya',
#  '3D Topographical Earth in Blender',
#  '3D Type in Adobe Illustrator made simple',
#  '3D Visualization For Beginners: Interior Scene with 3DS MAX',
#  '3D animation made easy with smart phone',
#  '3D character rigging for animation in Cinema 4D Masterclass',
#  '3D do ZERO à PÓS em 7 horas - Cinema 4D para Designers',
#  '3D in After Effects CC: Working & Animating in 3D Space',
#  '3D modeling & 3D printing with SELFCAD',
#  '3D | Curso Blender 2.8 | Renderização de Produto + Projetos',
#  '3D Интерьер 3.0 - Интеграция с Unreal Engine 4',
#  "3D's Max&Vray İç Mekan Aydınlatma",
#  "3D's Max- Vray Villa Dış mekan modelleme",
#  '3D-Design mit Autodesk Maya - Der Grundlagenkurs',
#  '3D-скульптинг и ретопология в Blender',
#  '3DMax Eğitim Seti İle Kısa Sürede Uzmanlaşın',
#  '3DS MAX 2019 do início ao avançado',
#  '3DS MAX 2020 Interior Design Beginners Course',
#  '3DS MAX CORONA RENDER PRO : YENİ BAŞLAYANLAR ve İLERİ SEVİYE',
#  '3DS MAX DIŞ CEPHE CORONA RENDER PRO',
#  '3DS MAX Modelleme Ve Keyshot Render Eğitimi',
#  '3DS MAX create Oreo Commercial VFX shot from start to finish',
#  '3DS MAX İLE MİMARİ MODELLEME TEKNİKLERİ',
#  '3DS MAX, Modélisation polygonale et Subdivision',
#  '3DS Max + Corona Render: do Básico ao Avançado sem enrolação',
#  '3DS Max + Corona wizualizacja kuchni',
#  '3DS Max - Car Modeling for Beginners',
#  '3DS Max - Modelowanie obiektów low poly',
#  '3DS Max - Интерьер с нуля 2.0',
#  '3DS Max 2014 Tutorial Video. 3DS Max For Beginners',
#  '3DS Max 2017 & Vray 3.40 عمل مشهد داخلي بالماكس',
#  '3DS Max Learn Basics Foundation Course',
#  '3DS Max, AutoCAD, Vray: Creating a Complete Interior Scene',
#  '3DSMax 2016 & Substance Painter for Videogame Production',
#  '3DSMax para quem tem medo de 3DSMax',
#  '3Ds MAX & Vray - Design 3D Modern Shop Project in 4.5 hrs.',
#  '3Ds Max & Vray Complete Exterior Visualization Project',
#  '3Ds Max + Vray: Profesional en ArchViz - Hybrid Wooden House',
#  '3Ds Max - Básico',
#  '3Ds Max Game Modeling: Complete 3D Modeling in 3Ds Max',
#  '3Ds Max Game Modeling: Create Game Assets in 3Ds Max',
#  '3Ds Max para Arquitetura, Maquete eletrônica e Cenografia',
#  '3Ds Max ve Vray ile realistik araba sahnesi oluşturmak',
#  '3DsMAX for beginners Quick learning',
#  '3Keys 2Success',
#  '3d Animation for Architecture 3ds max + Vray (phase 2)',
#  '3d Animation for Architecture 3ds max + Vray (phase 3)',
#  '3d Coat Sculpture Modelling, Retopo , UVs and Paint',
#  '3d People +3ds Max+ Vray + Photoshop',
#  '3d Texturing with Substance Designer and Substance Painter',
#  '3d max and corona| الدورة الشاملة لاحتراف',
#  '3d modelling - a Modo modeling guide',
#  '3d printing and designing with Fusion 360: Beginner to Pro',
#  '3d scanning course training for vector software; 3d printing',
#  '3d visualization , 3ds Max ,v-ray ,ps : 3D render the VILLA',
#  '3d visualization , 3ds max , v-ray : 3D Modeling the VILLA',
#  '3d visualization , 3ds max, V-ray, Ps : 3D render The Museum',
#  '3ds Max & Vray: Advanced Arch Viz Interior Projects',
#  '3ds Max + AE: Learn VFX, Camera Tracking and Compositing',
#  '3ds Max + Arnold: Do básico à sua primeira animação',
#  '3ds Max + Forest Pack: Create Realistic 3d Environments',
#  '3ds Max + V-Ray: 3ds Max PRO in 6 hrs',
#  '3ds Max + V-ray 3.0 Visualization 3+ hours',
#  '3ds Max + VRay : Automotive Studio Lights',
#  '3ds Max + VRay: Materials Masterclass',
#  '3ds Max + Vray : 3d Visualizer handbook to Interior daylight',
#  '3ds Max + Vray : Interior & Exterior Night Renders',
#  '3ds Max + Vray: Advanced Architectural Exteriors',
#  '3ds Max - Zaawansowane techniki modelowania - Turbosmooth',
#  '3ds Max 2018 & V-ray ile Başlangıçtan İleri Seviyeye !!',
#  '3ds Max 2019 Beginners Course',
#  '3ds Max 3d Animation Character Animation Modelling Autodesk',
#  '3ds Max : Aprenda 3D Studio Max do Básico ao Avançado',
#  '3ds Max : Ferramentas de Animação 3D, Arnold e After Effects',
#  '3ds Max Design: Tutorial for Revit Users.',
#  '3ds Max Mastery in 7 Hrs: Project Based Intro for Beginners',
#  '3ds Max UVW Unwrapping Mastered - From Beginner to Pro',
#  '3ds Max Zero to Hero: The Complete Guide To 3D Modeling',
#  '3ds Max e Photoshop CC - Maquete Eletrônica 3D (Externa)',
#  '3ds Max e V-Rray Textura, iluminação e Render Vol: 01',
#  '3ds Max e V-Rray Textura, iluminação e Render Vol: 02',
#  '3ds Max e V-Rray Textura, iluminação e Render Vol: 03',
#  '3ds Max e Vray: Criando a Cena de um Castelo.',
#  '3ds Max from scratch',
#  '3ds Max ile Sıfırdan İleri Seviyeye',
#  '3ds Max ve V-Ray Render ile Gerçekçi Dış Mekan Eğitimi 1',
#  '3ds Max ve Vray Render ile Baştan Sona Mimari Görselleştirme',
#  '3ds Max ve Vray ile İleri Görselleştirme Uzmanlığı Eğitimi',
#  '3ds Max İçin V-Ray NEXT Render Dersleri Detaylı Eğitim Seti',
#  '3ds Max 入門從零開始｜輕鬆學習3D建模',
#  '3ds Max: Arnold Render',
#  '3ds Max: Curso Completo de Rigging Facial e Corporal',
#  '3ds Max: Lighting in V-Ray Next Module 1 - The V-Ray Light',
#  '3ds Max: Model High-Poly Assets For Your Arch Viz Scenes',
#  "3ds Max: Modelleme ve Animasyon Sanatını A'dan Z'ye Öğrenin",
#  '3ds max + Corona Renderer: Creating Amazing Worlds',
#  '3ds max + Corona render : Creating Private Villa',
#  '3ds max 2020 Workflow Game Design PBR',
#  '3ds max Arnold Rendering e Light',
#  '3ds max Arnold i Materiali',
#  '3ds max Corona Rendering e Light.',
#  '3ds max Corona Rendering e Materiali',
#  '3ds max Corso Base UVW Mapping',
#  '3ds max Mass Fx Cloth Tessuti',
#  '3ds max Mentor: Getting Started in 3ds max',
#  '3ds max Modellazione Avanzata 1',
#  '3ds max Modellazione Avanzata Voxel Remesh',
#  '3ds max Modellazione Spline',
#  '3ds max Particle Systems 1',
#  '3ds max Unwrap Corso Completo',
#  '3ds max and V-ray for architect. Advanced 3d visualisation',
#  '3ds max and V-ray training for interior designers',
#  '3ds max and Vray advanced course. Furniture modeling.',
#  '3ds max for beginners',
#  '3ds max making of subway train',
#  '3ds max poligon modelleme',
#  '3ds max starter kit',
#  '3ds max ve Vray ile banyo modelleme, realistik render',
#  '3ds max: 3D Gaming modeling, Animation & Architect Designers',
#  '3Д моделирование в SketchUp',
#  '3時間でわかる！オープンデータを活用してビジネスチャンスを探索するための方法（情報収集、分析、考察～コンセプト立案）',
#  '4 Easy Geometry Drawing Techniques',
#  '4 Figure Stock Market Passive Income Without Picking Stocks',
#  '4 PMP Exam 2020, PMBOK 6th Edition, 800 Questions & Answers',
#  '4 Part Series: Become a Profitable Social Media Influencer',
#  '4 Passos Para Sair Do Vermelho',
#  "4 Steps to Rank #1 on Google's & Advanced SEO Tools Training",
#  '4 Steps to a Great Corporate Payments Process',
#  '4 Strategies that Will Make you a Professional Day Trader',
#  '4 Ways to Digitize Watercolor',
#  '4 стратегии для уверенной торговли на рынке Форекс',
#  '4. Ordinary Simple Annuities: The Basics',
#  '45 Ways to Get More Clients For Your Membership Site',
#  '47 Graphic Design Projects for Photoshop Beginners',
#  '48 Logo Designs and Techniques',
#  '49 Charts in Tableau 2020 - Basic to Intermediate',
#  '4in1 | Learn Photography, Wordpress, Video Editing, SEO, ...',
#  '4차 산업 혁명 시대, 초연결의 중심 모바일 컨텐츠 개발의 성공 안내서!',
#  '5 Bookkeeping Basics for Creative Entrepreneurs (US)',
#  '5 Characteristics of Successful Organizations',
#  '5 Courses - Master AWS, Analytics, Machine Learning, Bigdata',
#  '5 Cursos Em 1 | Combo Marketing Digital 2020',
#  '5 Derste Photoshop | Temel Seviye',
#  '5 Dicas Incríveis para sua Marca',
#  '5 Easy Steps To Increase Your Credit Score',
#  '5 Easy Steps to Make the Most of Your Finances',
#  '5 Email Marketing Automations Every Business Needs - [2020]',
#  '5 Ferramentas de gestão + Lego®',
#  '5 Figure Affiliate Business 2020',
#  '5 Indie Game Dev Techniques to Save & Load Data in Unity',
#  '5 Keys To Investing',
#  '5 MUST-HAVE AMAZON SOFTWARE TOOLS',
#  '5 Management tools + Lego®',
#  '5 Most Important Things Artists Need to Grow Social Media',
#  "5 P's of Marketing",
#  '5 Princípios Extraordinários de Infoprodutores de sucesso',
#  '5 SEO Secrets for 2020 & beyond - All you need to profit NOW',
#  '5 Sales-Video Strategies To Sell On YouTube Or Your Website',
#  '5 Simple Steps to Find & Define Your Niche',
#  '5 Step Blueprint For Author Platform Success',
#  '5 Step Creative Process to Branding',
#  '5 Step Marketing Plan - Get More Customers',
#  '5 Step Social Media Campaign: Facebook etc Laurel Papworth',
#  '5 Steps & 30 Mins : Composite Material Modeling (Digimat-HC)',
#  '5 Steps To Building Your Email List Quickly and Efficiently',
#  '5 Steps to Build & Manage Your Personal Brand Platform.',
#  '5 Steps to a Better Website',
#  '5 Top Marketing Mistakes And How To Avoid Them',
#  '5 Ways To Create Your Own Ebook',
#  '5 estratégia com indicadores para download',
#  '5 jours pour trouver le produit Gagnant avec ClickFunnels',
#  '5 modelos de posts p/ engajar e vender no instagram [2020]',
#  '5 pasos para tener tu estudio de diseño sin pago de licencia',
#  '5 programming languages Front End & Back End Web Development',
#  '5 weeks Social Media Championship Course',
#  '5) CBDM: Certified Business Data Modeler',
#  '5-Key Elements in Start-up Business with Low Capital Needs',
#  '5-Step Value Investing Formula',
#  '5. APICS CPIM Practice Questions (200 Questions)',
#  '5. Ordinary Simple Annuities : Advanced Problems.',
#  '50 Digital Marketing Hacks - Social Media Marketing Growth',
#  '50 FREE Tools That Will Make You a Better Writer',
#  '50 Growth Hacks & Case Studies to Boost your Startup',
#  '50 Informatica Interview Scenarios - Solved',
#  '50 Point SEO Audit For Your Site Or As Freelancer In 2020',
#  '50 Python Source Codes Explained',
#  '50 Sales Strategies for Entrepreneurs: Become A Sales Expert',
#  '50 Shades of UX Design',
#  "50 Things You've Been Doing Wrong in C# and .NET Core",
#  '50 Top Products You Should Import for Sale on Amazon or eBay',
#  '50+ Places To Work Online As A Freelancer',
#  '50-Minute SEO Crash Course',
#  '50.000 Fãs no Facebook: Como Crescer Sua Página Fácilmente',
#  '52 Scripts for Facebook Posts Creation',
#  '5S Workplace Management Technique',
#  "6 Challenges of Today's Voice Assistants Like Alexa",
#  '6 Cursos em 1 Blender Game Design 15 Horas',
#  '6 Killer Behavioral Economics Principles for Marketers, CX',
#  '6 Methods For Streamlining Your Staff Hiring Process',
#  '6 Secert Traffic Strategies To Sell More On Amazon Ebay Etsy',
#  '6 Shortcuts to Powerful Persuasion',
#  '6 Steps To Grow Your Machine Quilting Service Business',
#  '6 Steps To Proofreading Jumpstart',
#  '6 Steps to Creating a Non-Profit Organization or Ministry',
#  '6 Steps to Manifesting an Income Goal in Your Business',
#  '6 Ways To Make An Android, iPhone App With No Coding Skills',
#  '6 Years Of Internet Marketing Success & Failure',
#  '6 técnicas de storytelling para vender más a partir de hoy.',
#  '6 ways to generate leads starting from zero + FREE templates',
#  '6. Annuities Due and Deferred',
#  '6.5 Selling Tips on Craigslist',
#  '60 AutoCAD 2D & 3D Drawings and Practical Projects',
#  '60 Minute Complete Accounts for Freelancers, Basic to Pro',
#  '60 Minutes to Fundamental Accounting Skills',
#  '60 Videotutoriales de Photoshop CC. Aprende paso a paso',
#  '60-Minute Kotlin Quick Start for Java Developers',
#  '61% Profit In 1 Month - Crush Your Forex Trading Paradigm',
#  '65 Actionable Branding Strategies: 3x Your Traffic',
#  '67 Cognitive Biases That Can Help You Make More Money',
#  '7 ADVANCED Facebook Marketing Strategies That The Pros Know!',
#  '7 Advanced Quality Tools (Management & Planning Tools)',
#  "7 Amazon Product Launch Secrets Gurus Don't Want You To Know",
#  '7 Cursos em 1 Formação 3ds Max',
#  '7 Day List Building Machine',
#  '7 Day Ninja Traffic Plan',
#  '7 Days to more Impact and Influence on Social Media',
#  '7 Easy Steps to Create and Sell Content Online',
#  '7 Easy Steps to Plan/Upgrade to ISO 9001:2015',
#  '7 Estrategias para escribir y ganar dinero con tu libro',
#  '7 FIGURE Facebook Ads | 2019',
#  '7 FREE Digital Marketing Tools - Effective Online Marketing',
#  '7 Facebook Hacks For Improving Your Campaigns',
#  '7 Facets of Employee Engagement and 50 Ideas for Doing It',
#  '7 Figure Facebook Advertising For Realtors',
#  '7 Figure Secrets - How To Profit From Internet Like a #BOSS',
#  '7 GIMP Web Design Projects - Learn GIMP Web Design By Doing',
#  '7 INSANELY Profitable Amazon Product Research Methods (2020)',
#  '7 Key Steps to Blogging Mastery',
#  '7 Key Tools for Social Media Success Today (in fashion)',
#  '7 Keys To Success When Developing Your Smart Product Design',
#  '7 Keys to Succeed as a Freelancer',
#  '7 Lessons on Writing for Becoming a Standout Writer',
#  '7 PR Secrets All Nonprofits Should Know',
#  '7 Pasos para tener Presencia en Internet',
#  '7 Passive Income Ideas & Strategies That Actually Profit',
#  '7 Pecados Capitais Financeiros',
#  '7 Principles to accelerate your business by Amit Ambegaonkar',
#  '7 Proven Product Creation Ideas For Newbies',
#  '7 Proven Steps to Real Estate Success',
#  '7 Proven Steps to Self-Publishing',
#  '7 Quality Tools for Quality Management',
#  '7 Reasons Your IT or Other Projects May Fail',
#  '7 STEPS-TO-SUCCESS FOR FASHION INDUSTRY START-UP',
#  '7 Secrets To Designing In Black and White',
#  '7 Steps to Building Your Brand Using Twitter',
#  '7 Steps to Creating a Killer Exhibition Proposal',
#  '7 Steps to Generate New Business Models',
#  '7 Steps to Gothic Calligraphy',
#  '7 Steps to Successful Social Media for Your Business',
#  '7 Steps to a Perfectly Written Business Plan',
#  '7 Steps: Your Introduction to Trading',
#  '7 Strategies For Content Creation',
#  '7 Strategies for Limitless Business',
#  '7 Tips For Running A Creative Design Studio',
#  '7 Top Instagram AR Filters or Effects in Spark AR Studio',
#  "7 WAYS TO FIND GRANTS ON INTERNET WHEN GOOGLE WON'T SHOW YOU",
#  '7 Ways in 7 Days to Magnetise your Ideal Client',
#  '7 Ways to Improve Your QuickBooks Online Workflow',
#  '7 Website Mistakes Killing Your Sales & How To Fix Them',
#  '7 conceptos básicos de Feng Shui que debes conocer',
#  '7 courses in 1 - Diploma in Business Management',
#  '7 steps to effective Performance Management Conversations',
#  '7 unverzichtbare Inhalte für erfolgreiche Landing Pages!',
#  '7 étapes de vente Facebook pour passer en hypercroissance',
#  '7 天 SEO 挑戰賽 - 教你如何將關鍵字排在Google第一頁的技巧 (廣東話)',
#  '7-Step Guide to Trading',
#  '7-Step Technology Startup Success Formula',
#  '7. General Annuities',
#  "70 ECPM Not Magic it's knowledge - Chartboost Revnue Course",
#  '70-532 Microsoft Azure Certification: App Services Deep Dive',
#  '70-761: Querying Data with Transact-SQL Introductory Course',
#  '70以上のレッスンで、基礎からしっかり学べる！ HTML5完全マスターコース',
#  '72 Hour Listing: Real Estate Marketing Plan to Sell Homes',
#  '8 Derste Photoshop | Orta Seviye',
#  '8 Different Ways to Develop a Business Online',
#  '8 Essential Topics for Getting Started in Photoshop',
#  '8 INSANELY Profitable Amazon PPC Campaigns (Step-by-Step)',
#  '8 Major Forms of Waste in Organizations',
#  '8 Projects to learn Adobe Illustrator',
#  '8 Reasons Why Teams Fail - How to Overcome Team Failure',
#  '8 Simple Steps To Automating Tumblr For Profit',
#  '8 Steps To Achieve Financial Freedom And Escape Debt',
#  '8 Steps to Wealth through Real Estate',
#  '8 Steps to start your business',
#  '8 Stunden professionelles Cinema 4D Training',
#  '8 Things Everyone Should Know About Social Entrepreneurship',
#  '8 to Infinity - Color Mixing Course',
#  '8. Amortization Schedules',
#  '80 Derste Baştan Sona ZBrush',
#  '80 Xcode Tips To Improve Productivity - Xcode 9 iOS11 Swift4',
#  '8D Problem Solving',
#  '9 Leadership Principles for becoming a powerful Team Leader',
#  '9 Questions That You Need On ALL Surveys & Questionnaires',
#  '9 Secrets of SEO Writing',
#  '9 to 5 Breakout: Escape the Grind in 5 Easy Steps',
#  '9 trucos para encontrar trabajo',
#  '9. Sinking Funds',
#  '90 Days To Freedom Business Training Programme',
#  '90 Günlük Eylem Planı',
#  '90 Minute Contact Manager in FileMaker Pro',
#  '96 Skutecznych Sposobów Na Podwojenie Sprzedaży w Biznesie',
#  '99 Inspiring School Improvement Ideas',
#  '99 SCHOOL MANAGEMENT STRATEGIES',
#  '9A0-019 Adobe Photoshop 6.0 Product Certified Practice Exam',
#  '9A0-019 Adobe Photoshop 6.0 Product Proficiency Exam',
#  '9A0-031 Adobe Photoshop 7.0 Product Proficiency Exam',
#  '9A0-031 Adobe Photoshop 7.0 Product Proficieny Practice Exam',
#  '9A0-031 Adobe Photoshop7.0 Product Proficiency Practice Exam',
#  '9A0-036 Adobe Photo Shop CS ACE Certified Practice Exam',
#  '9A0-039 Adobe After Effects 6.0 Profession ACE Practice Exam',
#  '9A0-044 ACE Adobe Photoshop Certified Practice Exam',
#  '9A0-054 Adobe Photoshop CS3 ACE Certified Practice Exam',
#  '9A0-060 Adobe After Effects 7.0 Professional ACE Exam',
#  '9A0-094 Adobe Photoshop CS4 ACE Certified Practice Exam',
#  '9A0-150 Adobe Photoshop CS5 ACE Certified Practice Exam',
#  '9A0-303 Adobe Photoshop CS6 ACE Certified Practice Exam',
#  ':::Beginners Guide To Creating Amazing Images with Canva:::',
#  '</ZERO> Coding Algorithmic Trading with TSLab: Basics',
#  '?Cómo crear un Blog GRATIS ▶Crear Blog en BLOGGER FÁCIL',
#  "A 'DAN Z 'YE PİNTEREST PARA KAZANMA EĞİTİM SETİ ( PİNTOPİN )",
#  'A - Z Chart Pattern & Metatrader 4 Masterclass (NEW 2020)',
#  'A - Z Guide To Trade Forex Fundamental Analysis (2020)',
#  'A 16 Hour C# Course With Microsoft Visual Studio 2013',
#  'A 18 Hour SQL/SQL Server 2014/Visual Studio 2017 Course',
#  'A 3-Step Strategy to Start Organizing Your Business Finances',
#  'A Basic Understanding Of Hashtags',
#  'A Beginner introduction to Natural Language Processing',
#  "A Beginner's Angular Bootcamp 2020",
#  "A Beginner's Course on Spreadsheets for Personal Finance",
#  "A Beginner's Guide To : Sketchup 3D modeling",
#  "A Beginner's Guide To Choose The Best Franchise Option",
#  "A Beginner's Guide To Creating Database Driven Applications",
#  "A Beginner's Guide To Learn C++ Programming",
#  "A Beginner's Guide To Learn Machine Learning",
#  "A Beginner's Guide To Lern Web Development From Scratch",
#  "A Beginner's Guide To Machine Learning with Unity",
#  "A Beginner's Guide to Affiliate Marketing",
#  "A Beginner's Guide to Android App Development",
#  "A Beginner's Guide to Augmented Reality with Unity",
#  "A Beginner's Guide to Business Intelligence",
#  "A Beginner's Guide to Google Analytics",
#  "A Beginner's Guide to Hiring a Virtual Assistant on UpWork",
#  "A Beginner's Guide to Information Design for Communication",
#  "A Beginner's Guide to Low Poly Models in Blender!",
#  "A Beginner's Guide to Machine Learning (in Python)",
#  "A Beginner's Guide to Making Money Online",
#  "A Beginner's Guide to Numerical Methods in MATLAB",
#  "A Beginner's Guide to Pinterest Marketing",
#  "A Beginner's Guide to Python Programming Language",
#  "A Beginner's Guide to Replacing Your Job with Forex",
#  "A Beginner's Guide to Six Sigma",
#  ...]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=39436d08-244a-48f2-9b52-ac5d3c551bf2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
